# %%
from dask.distributed import Client, Executor, progress
from dask import dataframe as dd
import datetime
import numpy as np

# %%
client = Client('10.10.100.15:8786')

# %%
client
# Out:
# <Client: scheduler='tcp://10.10.100.15:8786' processes=18 cores=18>

# %%
client.get_versions(check=True)
# Out:
# {'client': {'host': [('python', '3.6.1.final.0'),
#    ('python-bits', 64),
#    ('OS', 'Linux'),
#    ('OS-release', '4.4.0-81-generic'),
#    ('machine', 'x86_64'),
#    ('processor', 'x86_64'),
#    ('byteorder', 'little'),
#    ('LC_ALL', 'None'),
#    ('LANG', 'en_US.UTF-8'),
#    ('LOCALE', 'en_US.UTF-8')],
#   'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#    'required': [('dask', '0.14.3'),
#     ('distributed', '1.16.3'),
#     ('msgpack', '0.4.8'),
#     ('cloudpickle', '0.2.2'),
#     ('toolz', '0.8.2')]}},
#  'scheduler': {'host': [['python', '3.6.1.final.0'],
#    ['python-bits', 64],
#    ['OS', 'Linux'],
#    ['OS-release', '4.4.0-81-generic'],
#    ['machine', 'x86_64'],
#    ['processor', 'x86_64'],
#    ['byteorder', 'little'],
#    ['LC_ALL', 'None'],
#    ['LANG', 'en_US.UTF-8'],
#    ['LOCALE', 'en_US.UTF-8']],
#   'packages': {'optional': [['numpy', '1.12.1'], ['pandas', '0.20.1']],
#    'required': [['dask', '0.14.3'],
#     ['distributed', '1.16.3'],
#     ['msgpack', '0.4.8'],
#     ['cloudpickle', '0.2.2'],
#     ['toolz', '0.8.2']]}},
#  'workers': {'tcp://10.10.100.11:36957': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.11:38014': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.11:41260': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.11:43851': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.11:45148': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.11:46721': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:33597': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:34027': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:34627': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:36888': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:40485': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.15:46535': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:36984': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:38319': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:38596': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:44823': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:45529': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}},
#   'tcp://10.10.100.4:46065': {'host': [('python', '3.6.1.final.0'),
#     ('python-bits', 64),
#     ('OS', 'Linux'),
#     ('OS-release', '4.4.0-81-generic'),
#     ('machine', 'x86_64'),
#     ('processor', 'x86_64'),
#     ('byteorder', 'little'),
#     ('LC_ALL', 'None'),
#     ('LANG', 'en_US.UTF-8'),
#     ('LOCALE', 'en_US.UTF-8')],
#    'packages': {'optional': [('numpy', '1.12.1'), ('pandas', '0.20.1')],
#     'required': [('dask', '0.14.3'),
#      ('distributed', '1.16.3'),
#      ('msgpack', '0.4.8'),
#      ('cloudpickle', '0.2.2'),
#      ('toolz', '0.8.2')]}}}}

# %%
# create the dataframe by reading in the CSV
csv = '/root/stackoverflow.csv'

# load the csv file into a dask dataframe
df = dd.read_csv(csv, parse_dates=['creationdate', 'acceptedAnswerCreationDate'])
df = client.persist(df)
progress(df)

# %%
df.head()
# Out:
#    Unnamed: 0  id  owneruserid  posttypeid        creationdate  \
# 0           0   4            8           1 2008-07-31 21:42:53
# 1           1   6            9           1 2008-07-31 22:08:09
# 2           2   9            1           1 2008-07-31 23:41:00
# 3           3  11            1           1 2008-07-31 23:55:38
# 4           4  13            9           1 2008-08-01 00:42:39
#
#    CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 0                  5               7.0    491           13      31416
# 1                  5              31.0    217            5      14712
# 2                  5            1404.0   1509           58     388201
# 3                  5            1248.0   1182           33     120658
# 4                  6               NaN    482           24     138485
#
#        ...        CommentCount  FavoriteCount           site acceptedAnswerId  \
# 0      ...                   4             37  stackoverflow              7.0
# 1      ...                   0              8  stackoverflow             31.0
# 2      ...                   6            341  stackoverflow           1404.0
# 3      ...                   3            517  stackoverflow           1248.0
# 4      ...                   3            123  stackoverflow          12446.0
#
#    acceptedAnswerCreationDate  acceptedAnswerCreationDayOfWeek  \
# 0         2008-07-31 22:17:58                              5.0
# 1         2008-08-01 12:22:52                              6.0
# 2         2008-08-04 16:50:06                              2.0
# 3         2008-08-04 13:57:26                              2.0
# 4         2008-08-15 16:27:32                              6.0
#
#   acceptedAnswerScore  acceptedAnswerCommentCount acceptedAnswerOwnerUserId  \
# 0               349.0                         1.0                       9.0
# 1               111.0                         0.0                       0.0
# 2              1403.0                        30.0                     212.0
# 3               792.0                        16.0                     268.0
# 4                64.0                         1.0                       5.0
#
#           site.1
# 0  stackoverflow
# 1  stackoverflow
# 2  stackoverflow
# 3  stackoverflow
# 4  stackoverflow
#
# [5 rows x 24 columns]

# %%
df.acceptedAnswerCreationDate
# Out:
# Dask Series Structure:
# npartitions=36
# None    datetime64[ns]
# None               ...
#              ...
# None               ...
# None               ...
# Name: acceptedAnswerCreationDate, dtype: datetime64[ns]
# Dask Name: getitem, 72 tasks

# %%
# count the number of total rows:
len(df)
# Out:
# 14015379

# %%
# inspect the data set
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'owneruserid', 'posttypeid', 'creationdate',
#        'CreationDayOfWeek', 'acceptedanswerid', 'score', 'answercount',
#        'viewcount', 'owneruserid.1', 'lasteditoruserid', 'lasteditdate',
#        'LastActivityDate', 'CommentCount', 'FavoriteCount', 'site',
#        'acceptedAnswerId', 'acceptedAnswerCreationDate',
#        'acceptedAnswerCreationDayOfWeek', 'acceptedAnswerScore',
#        'acceptedAnswerCommentCount', 'acceptedAnswerOwnerUserId', 'site.1'],
#       dtype='object')

# %%
# do some basic aggregation -- 
# compute the average number of answers for each day of the week
df.groupby(df.CreationDayOfWeek).answercount.mean().compute()
# Out:
# CreationDayOfWeek
# 1    1.538740
# 2    1.564522
# 3    1.581523
# 4    1.579910
# 5    1.579372
# 6    1.590603
# 7    1.547162
# Name: answercount, dtype: float64

# %%
# count number of rows with an accepted answer
len(df[(df.acceptedanswerid.notnull())])
# Out:
# 7561435

# %%
# count the number of rows without an accepted answer -- sanity check
len(df[(df.acceptedanswerid.isnull())])
# Out:
# 6453944

# %%
# create a new dataframe that only has the rows with an accepted answer:
df2 = df[(df.acceptedanswerid.notnull())]

# Also filter out rows where the acceptedAnswerCreationDate is before the creationdate
df3 = df[(df['acceptedAnswerCreationDate'] > df['creationdate'])]

# create a row that holds the time to answer, in seconds
df2['timeToAnswer'] = df2['acceptedAnswerCreationDate'] - df2['creationdate']
df3['timeToAnswer'] = df3['acceptedAnswerCreationDate'] - df3['creationdate']

# %%
len(df3)
# Out:
# 7561154

# %%
df3.timeToAnswer.head()
# Out:
# 0    0 days 00:35:05
# 1    0 days 14:14:43
# 2    3 days 17:09:06
# 3    3 days 14:01:48
# 4   14 days 15:44:53
# Name: timeToAnswer, dtype: timedelta64[ns]

# %%
df2.head()
# Out:
#    Unnamed: 0  id  owneruserid  posttypeid        creationdate  \
# 0           0   4            8           1 2008-07-31 21:42:53
# 1           1   6            9           1 2008-07-31 22:08:09
# 2           2   9            1           1 2008-07-31 23:41:00
# 3           3  11            1           1 2008-07-31 23:55:38
# 6           6  16            2           1 2008-08-01 04:59:34
#
#    CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 0                  5               7.0    491           13      31416
# 1                  5              31.0    217            5      14712
# 2                  5            1404.0   1509           58     388201
# 3                  5            1248.0   1182           33     120658
# 6                  6           12446.0     91            5      74191
#
#         ...        FavoriteCount           site acceptedAnswerId  \
# 0       ...                   37  stackoverflow              7.0
# 1       ...                    8  stackoverflow             31.0
# 2       ...                  341  stackoverflow           1404.0
# 3       ...                  517  stackoverflow           1248.0
# 6       ...                   13  stackoverflow            531.0
#
#   acceptedAnswerCreationDate  acceptedAnswerCreationDayOfWeek  \
# 0        2008-07-31 22:17:58                              5.0
# 1        2008-08-01 12:22:52                              6.0
# 2        2008-08-04 16:50:06                              2.0
# 3        2008-08-04 13:57:26                              2.0
# 6        2008-08-02 18:22:53                              7.0
#
#    acceptedAnswerScore acceptedAnswerCommentCount  acceptedAnswerOwnerUserId  \
# 0                349.0                        1.0                        9.0
# 1                111.0                        0.0                        0.0
# 2               1403.0                       30.0                      212.0
# 3                792.0                       16.0                      268.0
# 6                162.0                        2.0                      157.0
#
#           site.1    timeToAnswer
# 0  stackoverflow 0 days 00:35:05
# 1  stackoverflow 0 days 14:14:43
# 2  stackoverflow 3 days 17:09:06
# 3  stackoverflow 3 days 14:01:48
# 6  stackoverflow 1 days 13:23:19
#
# [5 rows x 25 columns]

# %%
# create a new column from the timeToAnswer timedelta column
df2['daysToAnswer'] = (df2['timeToAnswer'] / np.timedelta64(1, 'D')).astype(int)

# make a simple assumption that 30 days in a month
df2['monthsToAnswer'] = (df2['timeToAnswer'] / np.timedelta64(30, 'D')).astype(int)

# %%
# create a new column from the timeToAnswer timedelta column
df3['daysToAnswer'] = (df3['timeToAnswer'] / np.timedelta64(1, 'D')).astype(int)

# make a simple assumption that 30 days in a month
df3['monthsToAnswer'] = (df3['timeToAnswer'] / np.timedelta64(30, 'D')).astype(int)

# %%
df2.head()
# Out:
#    Unnamed: 0  id  owneruserid  posttypeid        creationdate  \
# 0           0   4            8           1 2008-07-31 21:42:53
# 1           1   6            9           1 2008-07-31 22:08:09
# 2           2   9            1           1 2008-07-31 23:41:00
# 3           3  11            1           1 2008-07-31 23:55:38
# 6           6  16            2           1 2008-08-01 04:59:34
#
#    CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 0                  5               7.0    491           13      31416
# 1                  5              31.0    217            5      14712
# 2                  5            1404.0   1509           58     388201
# 3                  5            1248.0   1182           33     120658
# 6                  6           12446.0     91            5      74191
#
#         ...        acceptedAnswerId  acceptedAnswerCreationDate  \
# 0       ...                     7.0         2008-07-31 22:17:58
# 1       ...                    31.0         2008-08-01 12:22:52
# 2       ...                  1404.0         2008-08-04 16:50:06
# 3       ...                  1248.0         2008-08-04 13:57:26
# 6       ...                   531.0         2008-08-02 18:22:53
#
#   acceptedAnswerCreationDayOfWeek acceptedAnswerScore  \
# 0                             5.0               349.0
# 1                             6.0               111.0
# 2                             2.0              1403.0
# 3                             2.0               792.0
# 6                             7.0               162.0
#
#    acceptedAnswerCommentCount  acceptedAnswerOwnerUserId         site.1  \
# 0                         1.0                        9.0  stackoverflow
# 1                         0.0                        0.0  stackoverflow
# 2                        30.0                      212.0  stackoverflow
# 3                        16.0                      268.0  stackoverflow
# 6                         2.0                      157.0  stackoverflow
#
#      timeToAnswer daysToAnswer  monthsToAnswer
# 0 0 days 00:35:05            0               0
# 1 0 days 14:14:43            0               0
# 2 3 days 17:09:06            3               0
# 3 3 days 14:01:48            3               0
# 6 1 days 13:23:19            1               0
#
# [5 rows x 27 columns]

# %%
#df2.monthsToAnswer.value_counts().compute()
df3.groupby('monthsToAnswer').count().compute()
# Out:
#                 Unnamed: 0      id  owneruserid  posttypeid  creationdate  \
# monthsToAnswer
# 0                    38054   38054        38054       38054         38054
# 1                   117763  117763       117763      117763        117763
# 2                   159730  159730       159730      159730        159730
# 3                   259275  259275       259275      259275        259275
# 4                   538631  538631       538631      538631        538631
# 5                   263313  263313       263313      263313        263313
# 6                   307447  307447       307447      307447        307447
# 7                   535396  535396       535396      535396        535396
# 8                   332646  332646       332646      332646        332646
# 9                   316091  316091       316091      316091        316091
# 10                  305859  305859       305859      305859        305859
# 11                  307416  307416       307416      307416        307416
# 12                  277607  277607       277607      277607        277607
# 13                  373902  373902       373902      373902        373902
# 14                  203629  203629       203629      203629        203629
# 15                  192258  192258       192258      192258        192258
# 16                  190003  190003       190003      190003        190003
# 17                  194003  194003       194003      194003        194003
# 18                  167666  167666       167666      167666        167666
# 19                  210798  210798       210798      210798        210798
# 20                  208022  208022       208022      208022        208022
# 21                  190640  190640       190640      190640        190640
# 22                  171257  171257       171257      171257        171257
# 23                  178725  178725       178725      178725        178725
# 24                  176620  176620       176620      176620        176620
# 25                  178179  178179       178179      178179        178179
# 26                  152431  152431       152431      152431        152431
# 27                  146249  146249       146249      146249        146249
# 28                  142454  142454       142454      142454        142454
# 29                  149976  149976       149976      149976        149976
# ...                    ...     ...          ...         ...           ...
# 75                      28      28           28          28            28
# 76                      28      28           28          28            28
# 77                      28      28           28          28            28
# 78                      24      24           24          24            24
# 79                      15      15           15          15            15
# 80                      13      13           13          13            13
# 81                      23      23           23          23            23
# 82                      16      16           16          16            16
# 83                      20      20           20          20            20
# 84                      12      12           12          12            12
# 85                      11      11           11          11            11
# 86                       7       7            7           7             7
# 87                      12      12           12          12            12
# 88                       7       7            7           7             7
# 89                      10      10           10          10            10
# 90                       9       9            9           9             9
# 91                       9       9            9           9             9
# 92                       7       7            7           7             7
# 93                       2       2            2           2             2
# 94                       4       4            4           4             4
# 95                       8       8            8           8             8
# 96                       5       5            5           5             5
# 97                       6       6            6           6             6
# 98                       2       2            2           2             2
# 99                       1       1            1           1             1
# 100                      4       4            4           4             4
# 101                      3       3            3           3             3
# 102                      2       2            2           2             2
# 103                      1       1            1           1             1
# 104                      1       1            1           1             1
#
#                 CreationDayOfWeek  acceptedanswerid   score  answercount  \
# monthsToAnswer
# 0                           38054             29247   38054        38054
# 1                          117763             86737  117763       117763
# 2                          159730            115459  159730       159730
# 3                          259275            188265  259275       259275
# 4                          538631            380584  538631       538631
# 5                          263313            181642  263313       263313
# 6                          307447            210334  307447       307447
# 7                          535396            364099  535396       535396
# 8                          332646            223215  332646       332646
# 9                          316091            206958  316091       316091
# 10                         305859            197113  305859       305859
# 11                         307416            194195  307416       307416
# 12                         277607            171295  277607       277607
# 13                         373902            224988  373902       373902
# 14                         203629            117786  203629       203629
# 15                         192258            109989  192258       192258
# 16                         190003            108625  190003       190003
# 17                         194003            109741  194003       194003
# 18                         167666             94820  167666       167666
# 19                         210798            118602  210798       210798
# 20                         208022            115447  208022       208022
# 21                         190640            105368  190640       190640
# 22                         171257             94222  171257       171257
# 23                         178725             99598  178725       178725
# 24                         176620             97407  176620       176620
# 25                         178179             96315  178179       178179
# 26                         152431             80642  152431       152431
# 27                         146249             77652  146249       146249
# 28                         142454             75511  142454       142454
# 29                         149976             79685  149976       149976
# ...                           ...               ...     ...          ...
# 75                             28                19      28           28
# 76                             28                19      28           28
# 77                             28                21      28           28
# 78                             24                17      24           24
# 79                             15                11      15           15
# 80                             13                11      13           13
# 81                             23                18      23           23
# 82                             16                12      16           16
# 83                             20                13      20           20
# 84                             12                 8      12           12
# 85                             11                 9      11           11
# 86                              7                 6       7            7
# 87                             12                 8      12           12
# 88                              7                 5       7            7
# 89                             10                 7      10           10
# 90                              9                 7       9            9
# 91                              9                 4       9            9
# 92                              7                 7       7            7
# 93                              2                 1       2            2
# 94                              4                 3       4            4
# 95                              8                 3       8            8
# 96                              5                 2       5            5
# 97                              6                 6       6            6
# 98                              2                 1       2            2
# 99                              1                 1       1            1
# 100                             4                 4       4            4
# 101                             3                 3       3            3
# 102                             2                 2       2            2
# 103                             1                 1       1            1
# 104                             1                 1       1            1
#
#                 viewcount      ...         site  acceptedAnswerId  \
# monthsToAnswer                 ...
# 0                   38054      ...        38054             38054
# 1                  117763      ...       117763            117763
# 2                  159730      ...       159730            159730
# 3                  259275      ...       259275            259275
# 4                  538631      ...       538631            538631
# 5                  263313      ...       263313            263313
# 6                  307447      ...       307447            307447
# 7                  535396      ...       535396            535396
# 8                  332646      ...       332646            332646
# 9                  316091      ...       316091            316091
# 10                 305859      ...       305859            305859
# 11                 307416      ...       307416            307416
# 12                 277607      ...       277607            277607
# 13                 373902      ...       373902            373902
# 14                 203629      ...       203629            203629
# 15                 192258      ...       192258            192258
# 16                 190003      ...       190003            190003
# 17                 194003      ...       194003            194003
# 18                 167666      ...       167666            167666
# 19                 210798      ...       210798            210798
# 20                 208022      ...       208022            208022
# 21                 190640      ...       190640            190640
# 22                 171257      ...       171257            171257
# 23                 178725      ...       178725            178725
# 24                 176620      ...       176620            176620
# 25                 178179      ...       178179            178179
# 26                 152431      ...       152431            152431
# 27                 146249      ...       146249            146249
# 28                 142454      ...       142454            142454
# 29                 149976      ...       149976            149976
# ...                   ...      ...          ...               ...
# 75                     28      ...           28                28
# 76                     28      ...           28                28
# 77                     28      ...           28                28
# 78                     24      ...           24                24
# 79                     15      ...           15                15
# 80                     13      ...           13                13
# 81                     23      ...           23                23
# 82                     16      ...           16                16
# 83                     20      ...           20                20
# 84                     12      ...           12                12
# 85                     11      ...           11                11
# 86                      7      ...            7                 7
# 87                     12      ...           12                12
# 88                      7      ...            7                 7
# 89                     10      ...           10                10
# 90                      9      ...            9                 9
# 91                      9      ...            9                 9
# 92                      7      ...            7                 7
# 93                      2      ...            2                 2
# 94                      4      ...            4                 4
# 95                      8      ...            8                 8
# 96                      5      ...            5                 5
# 97                      6      ...            6                 6
# 98                      2      ...            2                 2
# 99                      1      ...            1                 1
# 100                     4      ...            4                 4
# 101                     3      ...            3                 3
# 102                     2      ...            2                 2
# 103                     1      ...            1                 1
# 104                     1      ...            1                 1
#
#                 acceptedAnswerCreationDate  acceptedAnswerCreationDayOfWeek  \
# monthsToAnswer
# 0                                    38054                            38054
# 1                                   117763                           117763
# 2                                   159730                           159730
# 3                                   259275                           259275
# 4                                   538631                           538631
# 5                                   263313                           263313
# 6                                   307447                           307447
# 7                                   535396                           535396
# 8                                   332646                           332646
# 9                                   316091                           316091
# 10                                  305859                           305859
# 11                                  307416                           307416
# 12                                  277607                           277607
# 13                                  373902                           373902
# 14                                  203629                           203629
# 15                                  192258                           192258
# 16                                  190003                           190003
# 17                                  194003                           194003
# 18                                  167666                           167666
# 19                                  210798                           210798
# 20                                  208022                           208022
# 21                                  190640                           190640
# 22                                  171257                           171257
# 23                                  178725                           178725
# 24                                  176620                           176620
# 25                                  178179                           178179
# 26                                  152431                           152431
# 27                                  146249                           146249
# 28                                  142454                           142454
# 29                                  149976                           149976
# ...                                    ...                              ...
# 75                                      28                               28
# 76                                      28                               28
# 77                                      28                               28
# 78                                      24                               24
# 79                                      15                               15
# 80                                      13                               13
# 81                                      23                               23
# 82                                      16                               16
# 83                                      20                               20
# 84                                      12                               12
# 85                                      11                               11
# 86                                       7                                7
# 87                                      12                               12
# 88                                       7                                7
# 89                                      10                               10
# 90                                       9                                9
# 91                                       9                                9
# 92                                       7                                7
# 93                                       2                                2
# 94                                       4                                4
# 95                                       8                                8
# 96                                       5                                5
# 97                                       6                                6
# 98                                       2                                2
# 99                                       1                                1
# 100                                      4                                4
# 101                                      3                                3
# 102                                      2                                2
# 103                                      1                                1
# 104                                      1                                1
#
#                 acceptedAnswerScore  acceptedAnswerCommentCount  \
# monthsToAnswer
# 0                             38054                       38054
# 1                            117763                      117763
# 2                            159730                      159730
# 3                            259275                      259275
# 4                            538631                      538631
# 5                            263313                      263313
# 6                            307447                      307447
# 7                            535396                      535396
# 8                            332646                      332646
# 9                            316091                      316091
# 10                           305859                      305859
# 11                           307416                      307416
# 12                           277607                      277607
# 13                           373902                      373902
# 14                           203629                      203629
# 15                           192258                      192258
# 16                           190003                      190003
# 17                           194003                      194003
# 18                           167666                      167666
# 19                           210798                      210798
# 20                           208022                      208022
# 21                           190640                      190640
# 22                           171257                      171257
# 23                           178725                      178725
# 24                           176620                      176620
# 25                           178179                      178179
# 26                           152431                      152431
# 27                           146249                      146249
# 28                           142454                      142454
# 29                           149976                      149976
# ...                             ...                         ...
# 75                               28                          28
# 76                               28                          28
# 77                               28                          28
# 78                               24                          24
# 79                               15                          15
# 80                               13                          13
# 81                               23                          23
# 82                               16                          16
# 83                               20                          20
# 84                               12                          12
# 85                               11                          11
# 86                                7                           7
# 87                               12                          12
# 88                                7                           7
# 89                               10                          10
# 90                                9                           9
# 91                                9                           9
# 92                                7                           7
# 93                                2                           2
# 94                                4                           4
# 95                                8                           8
# 96                                5                           5
# 97                                6                           6
# 98                                2                           2
# 99                                1                           1
# 100                               4                           4
# 101                               3                           3
# 102                               2                           2
# 103                               1                           1
# 104                               1                           1
#
#                 acceptedAnswerOwnerUserId  site.1  timeToAnswer  daysToAnswer
# monthsToAnswer
# 0                                   38054   38054         38054         38054
# 1                                  117763  117763        117763        117763
# 2                                  159730  159730        159730        159730
# 3                                  259275  259275        259275        259275
# 4                                  538631  538631        538631        538631
# 5                                  263313  263313        263313        263313
# 6                                  307447  307447        307447        307447
# 7                                  535396  535396        535396        535396
# 8                                  332646  332646        332646        332646
# 9                                  316091  316091        316091        316091
# 10                                 305859  305859        305859        305859
# 11                                 307416  307416        307416        307416
# 12                                 277607  277607        277607        277607
# 13                                 373902  373902        373902        373902
# 14                                 203629  203629        203629        203629
# 15                                 192258  192258        192258        192258
# 16                                 190003  190003        190003        190003
# 17                                 194003  194003        194003        194003
# 18                                 167666  167666        167666        167666
# 19                                 210798  210798        210798        210798
# 20                                 208022  208022        208022        208022
# 21                                 190640  190640        190640        190640
# 22                                 171257  171257        171257        171257
# 23                                 178725  178725        178725        178725
# 24                                 176620  176620        176620        176620
# 25                                 178179  178179        178179        178179
# 26                                 152431  152431        152431        152431
# 27                                 146249  146249        146249        146249
# 28                                 142454  142454        142454        142454
# 29                                 149976  149976        149976        149976
# ...                                   ...     ...           ...           ...
# 75                                     28      28            28            28
# 76                                     28      28            28            28
# 77                                     28      28            28            28
# 78                                     24      24            24            24
# 79                                     15      15            15            15
# 80                                     13      13            13            13
# 81                                     23      23            23            23
# 82                                     16      16            16            16
# 83                                     20      20            20            20
# 84                                     12      12            12            12
# 85                                     11      11            11            11
# 86                                      7       7             7             7
# 87                                     12      12            12            12
# 88                                      7       7             7             7
# 89                                     10      10            10            10
# 90                                      9       9             9             9
# 91                                      9       9             9             9
# 92                                      7       7             7             7
# 93                                      2       2             2             2
# 94                                      4       4             4             4
# 95                                      8       8             8             8
# 96                                      5       5             5             5
# 97                                      6       6             6             6
# 98                                      2       2             2             2
# 99                                      1       1             1             1
# 100                                     4       4             4             4
# 101                                     3       3             3             3
# 102                                     2       2             2             2
# 103                                     1       1             1             1
# 104                                     1       1             1             1
#
# [105 rows x 26 columns]

# %%
# count the number of rows without an accepted answer creation date
len(df2)
# Out:
# 7561435

# %%
df2.timeToAnswer.head(1)
# Out:
# 0    2105
# Name: timeToAnswer, dtype: int64

# %%
import pandas as pd
def to_year(x):
    if x < 0:
        return 'neg'
    if x < 60*60*24*365:
        return 'year 1'
    if x < 60*60*24*365*2:
        return 'year 2'
    if x < 60*60*24*365*3:
        return 'year 3'
    if x < 60*60*24*365*4:
        return 'year 4'
    
df2.groupby(by=to_year)[df2.timeToAnswer]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-7f3b6fbc11a4> in <module>()
#      12         return 'year 4'
#      13
# ---> 14 df2.groupby(by=to_year)[df2.timeToAnswer]
#
# /root/anaconda3/lib/python3.6/site-packages/dask/dataframe/groupby.py in __getitem__(self, key)
#     985
#     986         # error is raised from pandas
# --> 987         g._meta = g._meta[key]
#     988         return g
#     989
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: Dask Series Structure:\nnpartitions=36\nNone    int64\nNone      ...\n        ...  \nNone      ...\nNone      ...\nName: timeToAnswer, dtype: int64\nDask Name: getitem, 252 tasks'

# %%
import numpy as np
pd.Series.hist(df2.timeToAnswer.astype(np.int))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f9197a51675c> in <module>()
#       1 import numpy as np
# ----> 2 pd.Series.hist(df2.timeToAnswer.astype(np.int))
#
# /root/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2191         values = self.dropna().values
#    2192
# -> 2193         ax.hist(values, bins=bins, **kwds)
#    2194         ax.grid(grid)
#    2195         axes = np.array([ax])
#
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6127
#    6128         # process the unit information
# -> 6129         self._process_unit_info(xdata=x, kwargs=kwargs)
#    6130         x = self.convert_xunits(x)
#    6131         if bin_range is not None:
#
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    1994             # we only need to update if there is nothing set yet.
#    1995             if not self.xaxis.have_units():
# -> 1996                 self.xaxis.update_units(xdata)
#    1997
#    1998         if ydata is not None:
#
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/axis.py in update_units(self, data)
#    1411         """
#    1412
# -> 1413         converter = munits.registry.get_converter(data)
#    1414         if converter is None:
#    1415             return False
#
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     159                 return converter
#     160
# --> 161         if converter is None and iterable(x) and (len(x) > 0):
#     162             thisx = safe_first_element(x)
#     163             if classx and classx != getattr(thisx, '__class__', None):
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
# what percentage of questions that have an accepted answer got that answer within: 
#   i) one hour of the original post?
#  ii) one day of the original post?
# iii) one week of the original post?
#  iv) two weeks of the original post?
df_i = df2[(df2.timeToAnswer < 60*60)]
df_ii = df2[(df2.timeToAnswer < 60*60*24)]
df_iii = df2[(df2.timeToAnswer < 60*60*24*7)]
df_iv = df2[(df2.timeToAnswer < 60*60*24*7*2)]

# %%
tot_within_hour = len(df_i)

# %%
tot_within_day = len(df_ii)

# %%
tot_within_week = len(df_iii)

# %%
tot_within_two_weekd = len(df_iv)

# %%
total = len(df2)
print("Within one hour: {}%".format(float(tot_within_hour)/total*100.0))
print("Within one day: {}%".format(float(tot_within_day)/total*100.0))
print("Within one week: {}%".format(float(tot_within_week)/total*100.0))
print("Within two weeks: {}%".format(float(tot_within_two_weekd)/total*100.0))
# Out:
# Within one hour: 38.33878093245528%
# Within one day: 38.343899008587655%
# Within one week: 38.47818568829858%
# Within two weeks: 38.554586530202265%

# %%
tot_within_hour
# Out:
# 2898962

# %%
tot_within_day
# Out:
# 2899349

# %%
tot_within_week
# Out:
# 2909503

# %%
tot_within_two_weekd
# Out:
# 2915280

# %%
df_month = df2[(df2.timeToAnswer < 60*60*24*7*4)]

# %%
within_month = len(df_month)
# Out:
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP 'tcp://10.10.100.15:8786'>
# tornado.application - ERROR - Exception in callback None
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 887, in start
#     fd_obj, handler_func = self._handlers[fd]
# KeyError: 58

# %%
within_month
# Out:
# 2926533

# %%
df2[(df2.timeToAnswer > 0)].mean().compute()
# Out:
# Unnamed: 0                         3.540919e+06
# id                                 1.261774e+07
# owneruserid                        1.105332e+06
# posttypeid                         1.000000e+00
# CreationDayOfWeek                  3.999107e+00
# acceptedanswerid                   1.278405e+07
# score                              3.762527e+00
# answercount                        2.126443e+00
# viewcount                          3.964038e+03
# owneruserid.1                      1.105332e+06
# lasteditoruserid                   9.195380e+05
# CommentCount                       1.604489e+00
# FavoriteCount                      1.211838e+00
# acceptedAnswerId                   1.987514e+07
# acceptedAnswerCreationDayOfWeek    4.000965e+00
# acceptedAnswerScore                4.515524e+00
# acceptedAnswerCommentCount         1.978022e+00
# acceptedAnswerOwnerUserId          1.412591e+06
# timeToAnswer                       3.621236e+07
# dtype: float64

# %%
len(df2[(df2.timeToAnswer > 0)])
# Out:
# 4662475

# %%
df2[(df2.timeToAnswer < 0)].head()
# Out:
#         Unnamed: 0       id  owneruserid  posttypeid         creationdate  \
# 182127      182127  1030715        95624           1  2009-06-23 05:07:17
#
#         CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 182127                  3         1031536.0      1            4       5388
#
#             ...       FavoriteCount           site acceptedAnswerId  \
# 182127      ...                   1  stackoverflow         237686.0
#
#        acceptedAnswerCreationDate  acceptedAnswerCreationDayOfWeek  \
# 182127        2008-10-26 07:19:22                              1.0
#
#         acceptedAnswerScore acceptedAnswerCommentCount  \
# 182127                 14.0                        0.0
#
#         acceptedAnswerOwnerUserId         site.1  timeToAnswer
# 182127                    16371.0  stackoverflow   -20728075.0
#
# [1 rows x 25 columns]

# %%
df3 = df[(df.creationdate > df.acceptedAnswerCreationDate)]

# %%
df3.head(n=10)
# Out:
#         Unnamed: 0       id  owneruserid  posttypeid         creationdate  \
# 164385      164385   946700       116834           1  2009-06-03 19:33:18
# 182127      182127  1030715        95624           1  2009-06-23 05:07:17
#
#         CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 164385                  4               NaN      4            5       3500
# 182127                  3         1031536.0      1            4       5388
#
#             ...        CommentCount  FavoriteCount           site  \
# 164385      ...                   0              9  stackoverflow
# 182127      ...                   0              1  stackoverflow
#
#        acceptedAnswerId  acceptedAnswerCreationDate  \
# 164385          84599.0         2008-09-17 15:37:46
# 182127         237686.0         2008-10-26 07:19:22
#
#         acceptedAnswerCreationDayOfWeek acceptedAnswerScore  \
# 164385                              4.0                15.0
# 182127                              1.0                14.0
#
#         acceptedAnswerCommentCount acceptedAnswerOwnerUserId         site.1
# 164385                         2.0                   13850.0  stackoverflow
# 182127                         0.0                   16371.0  stackoverflow
#
# [2 rows x 24 columns]

# %%
len(df3)
# Out:
# 40

# %%
df3[:10]
# Out:
# Dask DataFrame Structure:
#                Unnamed: 0     id owneruserid posttypeid creationdate CreationDayOfWeek acceptedanswerid  score answercount viewcount owneruserid.1 lasteditoruserid lasteditdate LastActivityDate CommentCount FavoriteCount    site acceptedAnswerId acceptedAnswerCreationDate acceptedAnswerCreationDayOfWeek acceptedAnswerScore acceptedAnswerCommentCount acceptedAnswerOwnerUserId  site.1
# npartitions=36
# None                int64  int64       int64      int64       object             int64          float64  int64       int64     int64         int64          float64       object           object        int64         int64  object          float64                     object                         float64             float64                    float64                   float64  object
# None                  ...    ...         ...        ...          ...               ...              ...    ...         ...       ...           ...              ...          ...              ...          ...           ...     ...              ...                        ...                             ...                 ...                        ...                       ...     ...
# ...                   ...    ...         ...        ...          ...               ...              ...    ...         ...       ...           ...              ...          ...              ...          ...           ...     ...              ...                        ...                             ...                 ...                        ...                       ...     ...
# None                  ...    ...         ...        ...          ...               ...              ...    ...         ...       ...           ...              ...          ...              ...          ...           ...     ...              ...                        ...                             ...                 ...                        ...                       ...     ...
# None                  ...    ...         ...        ...          ...               ...              ...    ...         ...       ...           ...              ...          ...              ...          ...           ...     ...              ...                        ...                             ...                 ...                        ...                       ...     ...
# Dask Name: try_loc, 216 tasks

# %%
df3.head(n=15, npartitions=-1)
# Out:
#         Unnamed: 0       id  owneruserid  posttypeid         creationdate  \
# 164385      164385   946700       116834           1  2009-06-03 19:33:18
# 182127      182127  1030715        95624           1  2009-06-23 05:07:17
# 34663       379353  1883316         8835           1  2009-12-10 19:19:59
# 134061      478751  2291015       171365           1  2010-02-18 18:13:26
# 81521       766924  3373073         4067           1  2010-07-30 15:41:02
# 258007      943410  4005873       485273           1  2010-10-23 20:15:53
# 67754      1433393  5727458       644384           1  2011-04-20 08:22:18
# 228674     1594313  6278921       522089           1  2011-06-08 12:48:57
# 85167      1789000  6945572       710502           1  2011-08-04 17:05:12
# 156720     1860553  7188670       911802           1  2011-08-25 10:17:36
# 124851     2166638  8218224       635636           1  2011-11-21 20:37:20
# 130748     2172535  8237794       331609           1  2011-11-23 05:42:29
# 227507     2269294  8562902       474270           1  2011-12-19 14:40:00
# 229069     2270856  8568066       721073           1  2011-12-19 21:53:01
# 236012     2277799  8591616       709406           1  2011-12-21 14:44:37
#
#         CreationDayOfWeek  acceptedanswerid  score  answercount  viewcount  \
# 164385                  4               NaN      4            5       3500
# 182127                  3         1031536.0      1            4       5388
# 34663                   5         2059165.0      1            2        547
# 134061                  5         2291050.0      0            2       3597
# 81521                   6               NaN      1            1        285
# 258007                  7               NaN      1            1      21049
# 67754                   4               NaN      5            2        702
# 228674                  4               NaN      2            3       3406
# 85167                   5         6945989.0      6            5      27481
# 156720                  5               NaN      0            2        863
# 124851                  2         8218297.0      0            3       8072
# 130748                  4         8238183.0      0            1        274
# 227507                  2         8563305.0      0            2        179
# 229069                  2         8568120.0      0            2         75
# 236012                  4               NaN      0            2        336
#
#             ...        CommentCount  FavoriteCount           site  \
# 164385      ...                   0              9  stackoverflow
# 182127      ...                   0              1  stackoverflow
# 34663       ...                   0              0  stackoverflow
# 134061      ...                   4              1  stackoverflow
# 81521       ...                   0              1  stackoverflow
# 258007      ...                   5              1  stackoverflow
# 67754       ...                   5              0  stackoverflow
# 228674      ...                   0              0  stackoverflow
# 85167       ...                   4              1  stackoverflow
# 156720      ...                   1              0  stackoverflow
# 124851      ...                   0              1  stackoverflow
# 130748      ...                   1              0  stackoverflow
# 227507      ...                   7              0  stackoverflow
# 229069      ...                   0              0  stackoverflow
# 236012      ...                   0              0  stackoverflow
#
#        acceptedAnswerId  acceptedAnswerCreationDate  \
# 164385          84599.0         2008-09-17 15:37:46
# 182127         237686.0         2008-10-26 07:19:22
# 34663         2443025.0         2009-08-07 13:18:47
# 134061        2970430.0         2009-12-08 15:03:11
# 81521         1882765.0         2009-12-10 17:51:20
# 258007        5328063.0         2010-03-27 21:17:28
# 67754         7785209.0         2011-01-22 15:27:38
# 228674        8577237.0         2010-12-23 20:28:06
# 85167         9542948.0         2010-11-29 10:01:25
# 156720        9898235.0         2011-05-09 09:51:05
# 124851       11432057.0         2009-08-28 09:48:10
# 130748       11461626.0         2011-01-23 06:41:15
# 227507       11952784.0         2011-11-11 19:46:09
# 229069       11960541.0         2011-09-02 09:34:42
# 236012       11995833.0         2010-11-20 01:13:36
#
#         acceptedAnswerCreationDayOfWeek acceptedAnswerScore  \
# 164385                              4.0                15.0
# 182127                              1.0                14.0
# 34663                               6.0                 3.0
# 134061                              3.0                 3.0
# 81521                               5.0               149.0
# 258007                              7.0                 3.0
# 67754                               7.0                 2.0
# 228674                              5.0                 6.0
# 85167                               2.0                 4.0
# 156720                              2.0                17.0
# 124851                              6.0                 2.0
# 130748                              1.0                16.0
# 227507                              6.0                 3.0
# 229069                              6.0                 8.0
# 236012                              7.0               110.0
#
#         acceptedAnswerCommentCount acceptedAnswerOwnerUserId         site.1
# 164385                         2.0                   13850.0  stackoverflow
# 182127                         0.0                   16371.0  stackoverflow
# 34663                          0.0                  107156.0  stackoverflow
# 134061                         5.0                       0.0  stackoverflow
# 81521                          4.0                  163053.0  stackoverflow
# 258007                         1.0                  187793.0  stackoverflow
# 67754                          1.0                  158483.0  stackoverflow
# 228674                         3.0                  276311.0  stackoverflow
# 85167                          0.0                  124238.0  stackoverflow
# 156720                         4.0                  310174.0  stackoverflow
# 124851                         1.0                    7498.0  stackoverflow
# 130748                         2.0                       0.0  stackoverflow
# 227507                         0.0                  164611.0  stackoverflow
# 229069                         0.0                  172261.0  stackoverflow
# 236012                         0.0                       0.0  stackoverflow
#
# [15 rows x 24 columns]

# %%
df4 = df[(df.creationdate <= df.acceptedAnswerCreationDate)]

# %%
len(df4)
# Out:
# 7561154

# %%
df5 = df[(df.creationdate.isnull())]

# %%
len(df5)
# Out:
# 0

# %%
df6 = df[(df.acceptedAnswerCreationDate.isnull())]

# %%
len(df6)
# Out:
# 6454185

# %%
7561435 + _
# Out:
# 14015620
